# %%
import pandas as pd
import tensorflow as tf

# %%
boston = pd.read_csv('https://raw.githubusercontent.com/hwaneGithub/hwaneGithub.github.io/master/Database/boston.csv')
print(boston.columns)
boston.head()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
x_data = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm',
                 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
y_data = boston[['medv']]
print(x_data.shape)
print(y_data.shape)
# Out:
# (506, 13)
# (506, 1)

# %%
# y = w1x1 + w2x2 + ... + w13x13 + b
X = tf.keras.layers.Input(shape=[13]) # 입력층 구성(13개)
Y = tf.keras.layers.Dense(1)(X)       # 출력층 구성(1개)

model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
model.fit(x_data, y_data, epochs=10000, verbose=0)
model.fit(x_data, y_data, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9594
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7605
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.3452
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7026
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.8481
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7840
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9225
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.0258
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9712
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.1600

# %%
print("Predictions: ", model.predict(x_data[0:5]))    # 예측값
y_data[0:5]   # 실제값
# Out:
# Predictions:  [[29.463718]
#  [24.356743]
#  [30.844593]
#  [29.422356]
#  [29.034836]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
