# %% [markdown]
# ### 1. 데이터 준비

# %%
import pandas as pd
import tensorflow as tf

# %%
boston = pd.read_csv('https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv')
boston.head(3)
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
#
# [3 rows x 14 columns]

# %%
x_data = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm',
                 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
y_data = boston[['medv']]
print(x_data.shape)
print(y_data.shape)
# Out:
# (506, 13)
# (506, 1)

# %% [markdown]
# ### 2. 모델 구조 생성

# %%
X = tf.keras.layers.Input(shape=[13]) # 입력층 구성(13개) == y = w1x1 + w2x2 + ... + w13x13 + b
H = tf.keras.layers.Dense(10, activation='swish')(X)
Y = tf.keras.layers.Dense(1)(H)       # 출력층 구성(1개)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
model.fit(x_data, y_data, epochs=1000, verbose=0)
model.fit(x_data, y_data, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.1032
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.9959
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.4703
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.7255
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 26.0660
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.0611
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.8770
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.9536
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.3300
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.6832

# %%
model.summary()   # 모델이 잘 만들어 졌는지 확인
                  # Param : 학습하는 가중치의 개수
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Predictions: ", model.predict(x_data[0:5]))    # 예측값
print(y_data[0:5])   # 실제값
# Out:
# Predictions:  [[30.229214]
#  [25.064022]
#  [31.460423]
#  [30.257748]
#  [29.789997]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
