# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# # 국내 일일 확진자

# %%
domestic = pd.read_csv('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/우리나라 코로나 일별 데이터.csv')
domestic
# Out:
#     Date_reported  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 0      2020-01-03          0                 0           0                  0
# 1      2020-01-04          0                 0           0                  0
# 2      2020-01-05          0                 0           0                  0
# 3      2020-01-06          0                 0           0                  0
# 4      2020-01-07          0                 0           0                  0
# ..            ...        ...               ...         ...                ...
# 307    2020-11-05        125             27050           1                475
# 308    2020-11-06        145             27195           1                476
# 309    2020-11-07         89             27284           1                477
# 310    2020-11-08        143             27427           1                478
# 311    2020-11-09        126             27553           2                480
#
# [312 rows x 5 columns]

# %%
domestic = domestic[['Date_reported','New_cases']]
domestic['Date_reported'] = domestic['Date_reported'].str.replace('-','')
domestic
# Out:
# <ipython-input-6-21c970a7e739>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domestic['Date_reported'] = domestic['Date_reported'].str.replace('-','')
#     Date_reported  New_cases
# 0        20200103          0
# 1        20200104          0
# 2        20200105          0
# 3        20200106          0
# 4        20200107          0
# ..            ...        ...
# 307      20201105        125
# 308      20201106        145
# 309      20201107         89
# 310      20201108        143
# 311      20201109        126
#
# [312 rows x 2 columns]

# %%
domestic['Date_reported'] = pd.to_datetime(domestic['Date_reported'], format='%Y%m%d')
domestic
# Out:
# <ipython-input-7-2f9f31468c99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   domestic['Date_reported'] = pd.to_datetime(domestic['Date_reported'], format='%Y%m%d')
#     Date_reported  New_cases
# 0      2020-01-03          0
# 1      2020-01-04          0
# 2      2020-01-05          0
# 3      2020-01-06          0
# 4      2020-01-07          0
# ..            ...        ...
# 307    2020-11-05        125
# 308    2020-11-06        145
# 309    2020-11-07         89
# 310    2020-11-08        143
# 311    2020-11-09        126
#
# [312 rows x 2 columns]

# %%
domestic = domestic.set_index('Date_reported')
domestic
# Out:
#                New_cases
# Date_reported
# 2020-01-03             0
# 2020-01-04             0
# 2020-01-05             0
# 2020-01-06             0
# 2020-01-07             0
# ...                  ...
# 2020-11-05           125
# 2020-11-06           145
# 2020-11-07            89
# 2020-11-08           143
# 2020-11-09           126
#
# [312 rows x 1 columns]

# %% [markdown]
# # 서울 일일 확진자

# %%
seoulData = pd.read_csv('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(서울).csv', engine='python' )
seoulData
# Out:
#         연번     확진일  환자번호  국적  환자정보    지역     여행력          접촉력  조치사항   상태  \
# 0     6372  11.08.   NaN NaN   NaN   강동구     NaN    기타 확진자 접촉   NaN  NaN
# 1     6371  11.08.   NaN NaN   NaN   서초구     NaN  용산구 소재 의류업체   NaN  NaN
# 2     6370  11.08.   NaN NaN   NaN   용산구     NaN     감염경로 조사중   NaN  NaN
# 3     6369  11.08.   NaN NaN   NaN  서대문구     NaN   타시도 확진자 접촉   NaN  NaN
# 4     6368  11.08.   NaN NaN   NaN   은평구     NaN   타시도 확진자 접촉   NaN  NaN
# ...    ...     ...   ...  ..   ...   ...     ...          ...   ...  ...
# 6367     5   1.31.   NaN NaN   NaN   성북구     NaN        #5 접촉   NaN   퇴원
# 6368     4   1.30.   NaN NaN   NaN   마포구  중국 우한시        해외 접촉   NaN   퇴원
# 6369     3   1.30.   NaN NaN   NaN   종로구     NaN        #3 접촉   NaN   퇴원
# 6370     2   1.30.   NaN NaN   NaN   중랑구  중국 우한시        해외 접촉   NaN   퇴원
# 6371     1   1.24.   NaN NaN   NaN   강서구  중국 우한시        해외 접촉   NaN   퇴원
#
#               이동경로                  등록일                  수정일 노출여부
# 0              NaN  2020-11-09 10:10:15  2020-11-09 10:10:15    Y
# 1              NaN  2020-11-09 10:10:15  2020-11-09 10:10:15    Y
# 2              NaN  2020-11-09 10:10:15  2020-11-09 10:10:15    Y
# 3              NaN  2020-11-09 10:10:15  2020-11-09 10:10:15    Y
# 4              NaN  2020-11-09 10:10:15  2020-11-09 10:10:15    Y
# ...            ...                  ...                  ...  ...
# 6367  이동경로 공개기간 경과  2020-11-09 10:10:02  2020-11-10 09:00:01    Y
# 6368  이동경로 공개기간 경과  2020-11-09 10:10:02  2020-11-10 09:00:01    Y
# 6369  이동경로 공개기간 경과  2020-11-09 10:10:02  2020-11-10 09:00:01    Y
# 6370  이동경로 공개기간 경과  2020-11-09 10:10:02  2020-11-10 09:00:01    Y
# 6371  이동경로 공개기간 경과  2020-11-09 10:10:02  2020-11-10 09:00:01    Y
#
# [6372 rows x 14 columns]

# %%
seoul = seoulData[['확진일']]
seoul['확진자 수'] = 1
seoul
# Out:
# <ipython-input-10-f7dc5005cd2f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul['확진자 수'] = 1
#          확진일  확진자 수
# 0     11.08.      1
# 1     11.08.      1
# 2     11.08.      1
# 3     11.08.      1
# 4     11.08.      1
# ...      ...    ...
# 6367   1.31.      1
# 6368   1.30.      1
# 6369   1.30.      1
# 6370   1.30.      1
# 6371   1.24.      1
#
# [6372 rows x 2 columns]

# %%
date = seoul['확진일']

# %%
def make_date(date):
    if date.find('-') == 1:
        date = '2020-'+'0'+date
    else:
        date = '2020-'+date
    if len(date) < 10:
        date = date[:8]+'0'+date[-1]
    return date        
date
# Out:
# 0       11.08.
# 1       11.08.
# 2       11.08.
# 3       11.08.
# 4       11.08.
#          ...
# 6367     1.31.
# 6368     1.30.
# 6369     1.30.
# 6370     1.30.
# 6371     1.24.
# Name: 확진일, Length: 6372, dtype: object

# %%
date = seoul['확진일'].str.rstrip('.').str.replace('.','-').apply(make_date)

# %%
date = pd.to_datetime(date, format='%Y-%m-%d')
seoul['확진일'] = date
seoul
# Out:
# <ipython-input-14-4e68babc4913>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul['확진일'] = date
#             확진일  확진자 수
# 0    2020-11-08      1
# 1    2020-11-08      1
# 2    2020-11-08      1
# 3    2020-11-08      1
# 4    2020-11-08      1
# ...         ...    ...
# 6367 2020-01-31      1
# 6368 2020-01-30      1
# 6369 2020-01-30      1
# 6370 2020-01-30      1
# 6371 2020-01-24      1
#
# [6372 rows x 2 columns]

# %%
seoul = seoul.groupby('확진일').count()
seoul
# Out:
#             확진자 수
# 확진일
# 2020-01-24      1
# 2020-01-30      3
# 2020-01-31      3
# 2020-02-02      1
# 2020-02-05      2
# ...           ...
# 2020-11-04     48
# 2020-11-05     40
# 2020-11-06     37
# 2020-11-07     54
# 2020-11-08     46
#
# [261 rows x 1 columns]

# %% [markdown]
# # 부산 일일 확진자

# %%
busanData = pd.read_excel('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(부산).xlsx')
busanData
# Out:
#             날짜  확진자(누계)  확진자(추가)  완치자(누계)  완치자(추가)  검사결과 음성(누계)    격리   격리해제
# 0   2020-11-10      598        1      551       15       160440  2743  54028
# 1   2020-11-09      597        1      551       15       160184  2760  53880
# 2   2020-11-08      596        1      549       13       159687  2744  53689
# 3   2020-11-07      595        1      549       13       159527  2570  53553
# 4   2020-11-06      594        1      546       13       158604  2489  53370
# ..         ...      ...      ...      ...      ...          ...   ...    ...
# 259 2020-02-25       51       13        0        0         1823   618     21
# 260 2020-02-24       38       22        0        0         1499   263     22
# 261 2020-02-23       16       11        0        0         1076   145     15
# 262 2020-02-22        5        3        0        0         1092   115     15
# 263 2020-02-21        2        2        0        0          613    15     15
#
# [264 rows x 8 columns]

# %%
busan = busanData[['날짜','확진자(추가)']]
busan
# Out:
#             날짜  확진자(추가)
# 0   2020-11-10        1
# 1   2020-11-09        1
# 2   2020-11-08        1
# 3   2020-11-07        1
# 4   2020-11-06        1
# ..         ...      ...
# 259 2020-02-25       13
# 260 2020-02-24       22
# 261 2020-02-23       11
# 262 2020-02-22        3
# 263 2020-02-21        2
#
# [264 rows x 2 columns]

# %%
busanDate = busan['날짜']
busanDate = pd.to_datetime(busanDate, format='%Y-%m-%d')
busan
# Out:
#             날짜  확진자(추가)
# 0   2020-11-10        1
# 1   2020-11-09        1
# 2   2020-11-08        1
# 3   2020-11-07        1
# 4   2020-11-06        1
# ..         ...      ...
# 259 2020-02-25       13
# 260 2020-02-24       22
# 261 2020-02-23       11
# 262 2020-02-22        3
# 263 2020-02-21        2
#
# [264 rows x 2 columns]

# %%
busan = busan.set_index('날짜')
busan
# Out:
#             확진자(추가)
# 날짜
# 2020-11-10        1
# 2020-11-09        1
# 2020-11-08        1
# 2020-11-07        1
# 2020-11-06        1
# ...             ...
# 2020-02-25       13
# 2020-02-24       22
# 2020-02-23       11
# 2020-02-22        3
# 2020-02-21        2
#
# [264 rows x 1 columns]

# %% [markdown]
# # 대전 일일 확진자

# %%
daejeonData = pd.read_excel('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(대전).xlsx')
daejeonData
# Out:
#      확진번호     질본   확진일자 성별(연령대)          거주지               접촉력  \
# 0     445  27354  11.07     50대          유성구            역학조사 중
# 1     444  27257  11.06     40대           서구  대전 431번 확진자의 접촉자
# 2     443  26886  11.03     50대          유성구  대전 440번 확진자의 접촉자
# 3     442  26130  10.27     20대          대덕구       하남 확진자의 접촉자
# 4     441  26120  10.27     20대          유성구  대전 440번 확진자의 접촉자
# ..    ...    ...    ...     ...          ...               ...
# 440     5   1252   2.26   (30대)           유성               NaN
# 441     4   1256   2.26   (40대)           유성               NaN
# 442     3    573   2.23   (60대)           유성    대전 2번 확진자의 접촉자
# 443     2    372   2.22   (60대)           유성               NaN
# 444     1    241   2.21   (20대)  서울 (동구에 포함)               NaN
#
#                  조치사항
# 0          충남대학교병원 입원
# 1          충남대학교병원 입원
# 2          충남대학교병원 입원
# 3    충청·중앙3 생활치료센터 입원
# 4    충청·중앙3 생활치료센터 입원
# ..                ...
# 440          완치(3.09)
# 441          완치(3.02)
# 442          완치(5.05)
# 443          완치(3.28)
# 444          완치(3.04)
#
# [445 rows x 7 columns]

# %%
daejeon = daejeonData[['확진일자']]
daejeon['확진자 수'] = 1
daejeon
# Out:
# <ipython-input-21-b11427529fad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daejeon['확진자 수'] = 1
#       확진일자  확진자 수
# 0    11.07      1
# 1    11.06      1
# 2    11.03      1
# 3    10.27      1
# 4    10.27      1
# ..     ...    ...
# 440   2.26      1
# 441   2.26      1
# 442   2.23      1
# 443   2.22      1
# 444   2.21      1
#
# [445 rows x 2 columns]

# %%
daejeonDate = daejeon['확진일자']
daejeonDate = daejeonDate.astype(str)
daejeonDate
# Out:
# 0      11.07
# 1      11.06
# 2      11.03
# 3      10.27
# 4      10.27
#        ...
# 440     2.26
# 441     2.26
# 442     2.23
# 443     2.22
# 444     2.21
# Name: 확진일자, Length: 445, dtype: object

# %%
def make_date(daejeonDate):
    if daejeonDate.find('-') == 1:
        daejeonDate = '2020-'+'0'+ daejeonDate
    else:
        daejeonDate = '2020-'+ daejeonDate
    if len(daejeonDate) < 10:
        daejeonDate = daejeonDate[:8] +'0'+ daejeonDate[-1]
    return daejeonDate        
daejeonDate
# Out:
# 0      11.07
# 1      11.06
# 2      11.03
# 3      10.27
# 4      10.27
#        ...
# 440     2.26
# 441     2.26
# 442     2.23
# 443     2.22
# 444     2.21
# Name: 확진일자, Length: 445, dtype: object

# %%
daejeonDate = daejeonDate.str.replace('.','-').apply(make_date)
daejeonDate = pd.to_datetime(daejeonDate, format='%Y-%m-%d')
daejeon['확진일자'] = daejeonDate
# Out:
# <ipython-input-24-5939d32947d3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daejeon['확진일자'] = daejeonDate

# %%
daejeon = daejeon.groupby('확진일자').count()                                 
daejeon
# Out:
#             확진자 수
# 확진일자
# 2020-02-21      1
# 2020-02-22      1
# 2020-02-23      1
# 2020-02-26      6
# 2020-02-27      1
# ...           ...
# 2020-10-26      6
# 2020-10-27      6
# 2020-11-03      1
# 2020-11-06      1
# 2020-11-07      1
#
# [116 rows x 1 columns]

# %% [markdown]
# # 울산 일일 확진자

# %%
ulsanData = pd.read_excel('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(울산).xlsx')
ulsanData
# Out:
#          환자        확진일  거주지           감염경로
# 0    울산#166 2020-11-06   남구    해외입국(에티오피아)
# 1    울산#165 2020-11-03  울주군  해외입국(아랍에미레이트)
# 2    울산#164 2020-11-01   동구    해외입국(인도네시아)
# 3    울산#163 2020-10-29   중구       해외입국(미국)
# 4    울산#162 2020-10-28   중구   해외입국(우즈베키스탄)
# ..      ...        ...  ...            ...
# 165    울산#5 2020-02-26   남구      신천지 예배 참석
# 166    울산#4 2020-02-25   동구  확진자(경북 경산) 접촉
# 167    울산#3 2020-02-25   중구      신천지 예배 참석
# 168    울산#2 2020-02-24   중구      신천지 예배 참석
# 169    울산#1 2020-02-22  울주군      신천지 예배 참석
#
# [170 rows x 4 columns]

# %%
#ulsanData['확진일'] = ulsanData['확진일']
ulsanData.dtypes
# Out:
# 환자              object
# 확진일     datetime64[ns]
# 거주지             object
# 감염경로            object
# dtype: object

# %%
ulsan = ulsanData[['확진일']]
ulsan['확진자 수'] = 1
ulsan = ulsan.groupby('확진일').count()
ulsan
# Out:
# <ipython-input-28-f2c31a662fa1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ulsan['확진자 수'] = 1
#             확진자 수
# 확진일
# 2020-02-22      1
# 2020-02-24      1
# 2020-02-25      2
# 2020-02-26      1
# 2020-02-27      6
# ...           ...
# 2020-10-28      3
# 2020-10-29      1
# 2020-11-01      1
# 2020-11-03      1
# 2020-11-06      1
#
# [76 rows x 1 columns]

# %% [markdown]
# # 경기 일일 확진자

# %%
gyeonggi = pd.read_csv('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(경기).csv')
gyeonggi
# Out:
#     기준일(발병일, 확진일 선택)  레코드 수
# 0       2020. 11. 9.     21
# 1       2020. 11. 8.     23
# 2       2020. 11. 7.     29
# 3       2020. 11. 6.     28
# 4       2020. 11. 5.     43
# ..               ...    ...
# 262      2020. 2. 5.      2
# 263      2020. 2. 2.      2
# 264      2020. 2. 1.      1
# 265     2020. 1. 27.      1
# 266     2020. 1. 26.      1
#
# [267 rows x 2 columns]

# %%
gyeonggiDate = gyeonggi['기준일(발병일, 확진일 선택)'].str.replace('. ','-').str.strip('.')
gyeonggiDate = pd.to_datetime(gyeonggiDate)
gyeonggi['기준일(발병일, 확진일 선택)'] = gyeonggiDate
gyeonggi = gyeonggi.set_index('기준일(발병일, 확진일 선택)')
gyeonggi
# Out:
#                   레코드 수
# 기준일(발병일, 확진일 선택)
# 2020-11-09           21
# 2020-11-08           23
# 2020-11-07           29
# 2020-11-06           28
# 2020-11-05           43
# ...                 ...
# 2020-02-05            2
# 2020-02-02            2
# 2020-02-01            1
# 2020-01-27            1
# 2020-01-26            1
#
# [267 rows x 1 columns]

# %% [markdown]
# # 충북 일일 확진자

# %%
chungbukData = pd.read_excel('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(충북).xlsx')
chungbukData
# Out:
#                  날짜     확진일   연령      거주지              감염경로   조치사항
# 0     충북-205(청주105)  11.10.  60대  청주시 청원구               조사중    조치중
# 1    충북-204(청주시104)  11.10.  20대  청주시 청원구         해외입국자(독일)  청주의료원
# 2     충북-203(청주103)  11.09.  30대  청주시 흥덕구               조사중  청주의료원
# 3      충북-202(충주23)  11.09.  20대      충주시       해외입국자(이탈리아)  청주의료원
# 4     충북-201(청주102)  11.08.  20대  청주시 서원구  충북-197(청주99) 접촉자  청주의료원
# ..              ...     ...  ...      ...               ...    ...
# 187            충북-5  02.25.  30대      충주시                 -      -
# 188            충북-4  02.25.  50대      음성군                 -      -
# 189            충북-3  02.22.  30대      청주시                 -      -
# 190            충북-2  02.22.  30대      청주시                 -      -
# 191            충북-1  02.20.  30대      증평군                 -      -
#
# [192 rows x 6 columns]

# %%
chungbuk = chungbukData[['확진일']]
chungbuk['확진자 수'] = 1
chungbuk
# Out:
# <ipython-input-32-13103c1caab1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chungbuk['확진자 수'] = 1
#         확진일  확진자 수
# 0    11.10.      1
# 1    11.10.      1
# 2    11.09.      1
# 3    11.09.      1
# 4    11.08.      1
# ..      ...    ...
# 187  02.25.      1
# 188  02.25.      1
# 189  02.22.      1
# 190  02.22.      1
# 191  02.20.      1
#
# [192 rows x 2 columns]

# %%
chungbukDate = chungbuk['확진일'].str.rstrip('.').str.replace('.','-')
chungbukDate = '2020-' + chungbukDate

# %%
chungbukDate = pd.to_datetime(chungbukDate, format='%Y-%m-%d')
chungbuk['확진일'] = chungbukDate
chungbuk
# Out:
# <ipython-input-34-1a05335d2785>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chungbuk['확진일'] = chungbukDate
#            확진일  확진자 수
# 0   2020-11-10      1
# 1   2020-11-10      1
# 2   2020-11-09      1
# 3   2020-11-09      1
# 4   2020-11-08      1
# ..         ...    ...
# 187 2020-02-25      1
# 188 2020-02-25      1
# 189 2020-02-22      1
# 190 2020-02-22      1
# 191 2020-02-20      1
#
# [192 rows x 2 columns]

# %%
chungbuk = chungbuk.groupby('확진일').count()
chungbuk
# Out:
#             확진자 수
# 확진일
# 2020-02-20      1
# 2020-02-22      2
# 2020-02-25      3
# 2020-02-26      1
# 2020-02-27      3
# ...           ...
# 2020-11-04      1
# 2020-11-07      2
# 2020-11-08      4
# 2020-11-09      2
# 2020-11-10      2
#
# [102 rows x 1 columns]

# %% [markdown]
# # 경남 일일 확진자

# %%
gyeongnamData = pd.read_excel('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(경남).xlsx')
gyeongnamData
# Out:
#         환자 거주지        확진일
# 0    경남369  거제 2020-11-10
# 1    경남368  사천 2020-11-10
# 2    경남367  사천 2020-11-10
# 3    경남366  사천 2020-11-10
# 4    경남365  사천 2020-11-10
# ..     ...  ..        ...
# 360    경남5  창원 2020-02-22
# 361    경남4  진주 2020-02-21
# 362    경남3  진주 2020-02-21
# 363    경남2  합천 2020-02-20
# 364    경남1  합천 2020-02-20
#
# [365 rows x 3 columns]

# %%
gyeongnam = gyeongnamData[['확진일']]
gyeongnam['확진일'] = pd.to_datetime(gyeongnam['확진일'], format='%Y-%m-%d')
gyeongnam['확진자 수'] = 1
gyeongnam
# Out:
# <ipython-input-37-b91eb9c61b80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gyeongnam['확진일'] = pd.to_datetime(gyeongnam['확진일'], format='%Y-%m-%d')
# <ipython-input-37-b91eb9c61b80>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gyeongnam['확진자 수'] = 1
#            확진일  확진자 수
# 0   2020-11-10      1
# 1   2020-11-10      1
# 2   2020-11-10      1
# 3   2020-11-10      1
# 4   2020-11-10      1
# ..         ...    ...
# 360 2020-02-22      1
# 361 2020-02-21      1
# 362 2020-02-21      1
# 363 2020-02-20      1
# 364 2020-02-20      1
#
# [365 rows x 2 columns]

# %%
gyeongnam = gyeongnam.groupby('확진일').count()
gyeongnam
# Out:
#             확진자 수
# 확진일
# 2020-02-20      2
# 2020-02-21      2
# 2020-02-22      3
# 2020-02-23      9
# 2020-02-24      6
# ...           ...
# 2020-11-06      5
# 2020-11-07     10
# 2020-11-08      4
# 2020-11-09      2
# 2020-11-10     10
#
# [135 rows x 1 columns]

# %% [markdown]
# # 전국&시도 일일 확진자

# %% [markdown]
# ## 전국 포함

# %%
cases = pd.concat([domestic, seoul, busan], axis=1)
cases = cases.fillna(0).astype(int)
cases.columns = ['전국','서울','부산']
cases
# Out:
#              전국  서울  부산
# 2020-01-03    0   0   0
# 2020-01-04    0   0   0
# 2020-01-05    0   0   0
# 2020-01-06    0   0   0
# 2020-01-07    0   0   0
# ...         ...  ..  ..
# 2020-11-06  145  37   1
# 2020-11-07   89  54   1
# 2020-11-08  143  46   1
# 2020-11-09  126   0   1
# 2020-11-10    0   0   1
#
# [313 rows x 3 columns]

# %% [markdown]
# ## 전국 미포함

# %%
cityCases = pd.concat([seoul, busan, daejeon, ulsan, gyeonggi, chungbuk, gyeongnam], axis=1)
cityCases = cityCases.fillna(0).astype(int)
cityCases.columns = ['서울','부산','대전','울산','경기','충북','경남']
cityCases.to_csv('C:/Users/shine/Desktop/BigData/Mentoring/관련데이터/시도별 코로나 일일 확진자 현황(전체).csv', encoding='utf-8-sig')
cityCases
# Out:
#             서울  부산  대전  울산  경기  충북  경남
# 2020-01-24   1   0   0   0   0   0   0
# 2020-01-26   0   0   0   0   1   0   0
# 2020-01-27   0   0   0   0   1   0   0
# 2020-01-30   3   0   0   0   0   0   0
# 2020-01-31   3   0   0   0   0   0   0
# ...         ..  ..  ..  ..  ..  ..  ..
# 2020-11-06  37   1   1   1  28   0   5
# 2020-11-07  54   1   1   0  29   2  10
# 2020-11-08  46   1   0   0  23   4   4
# 2020-11-09   0   1   0   0  21   2   2
# 2020-11-10   0   1   0   0   0   2  10
#
# [280 rows x 7 columns]

# %% [markdown]
# # 시계열 그래프

# %% [markdown]
# ## 전국 포함

# %%
plt.figure(figsize=(10,7))
plt.title('일별 코로나 확진자 수', pad=20, fontweight='bold', fontsize = 20)     # 제목 설정
plt.plot(cases, linewidth=1)
plt.xlabel('날짜', fontweight='bold', fontsize = 20)     # x,y축 label 설정
plt.ylabel('확진자 수', fontweight='bold', fontsize = 20)
plt.grid(True)     # 격자 표시

# %% [markdown]
# ## 전국 미포함

# %%
plt.figure(figsize=(10,7))
plt.title('일별 코로나 확진자 수', pad=20, fontweight='bold', fontsize = 20)     # 제목 설정
plt.plot(cityCases, linewidth=1)
plt.xlabel('날짜', fontweight='bold', fontsize = 20)     # x,y축 label 설정
plt.ylabel('확진자 수', fontweight='bold', fontsize = 20)
plt.legend(['서울','부산','대전','울산','경기','충북','경남'], loc='upper left')
plt.grid(True)     # 격자 표시
plt.show()
